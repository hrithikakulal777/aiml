# %% [markdown]
# <a href="https://colab.research.google.com/github/hrithikakulal777/aiml/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,mean_absolute_error
df=pd.read_csv('/content/houseing.csv')
print(df)
df.info()
print(df.isnull().sum())
print(df.head())
plt.scatter(df.Built_up_area,df.Rent,color='red',marker='*')
plt.xlabel('Built_up_area')
plt.ylabel('Rent')
plt.show()
x=df.drop('Rent',axis=1)
print(x)
y=df.Rent
print(y)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.33,random_state=42)
print("xtrain shape:",xtrain.shape)
print("xtest shape:",xtest.shape)
print("ytrain shape:",ytrain.shape)
print("ytest shape:",ytest.shape)
reg=linear_model.LinearRegression()
reg.fit(x,y)
print(reg.coef_)
print(reg.intercept_)
z=9.7900215*650+1128.87925361797
print(z)
train_score=reg.score(xtrain,ytrain)
test_score=reg.score(xtest,ytest)
print('train score(R-squared):',train_score)
print('test score(R-squared):',test_score)

mse=mean_squared_error(ytest,y_pred)
mae=mean_absolute_error(ytest,y_pred)
print('mean squared error:',mse)
print('mean absolute error:',mae)
# Out:
#      Built_up_area  Rent  PTRATIO    MEDV
# 0            6.575  4.98     15.3  504000
# 1            6.421  9.14     17.8  453600
# 2            7.185  4.03     17.8  728700
# 3            6.998  2.94     18.7  701400
# 4            7.147  5.33     18.7  760200
# ..             ...   ...      ...     ...
# 484          6.593  9.67     21.0  470400
# 485          6.120  9.08     21.0  432600
# 486          6.976  5.64     21.0  501900
# 487          6.794  6.48     21.0  462000
# 488          6.030  7.88     21.0  249900
#
# [489 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Built_up_area  489 non-null    float64
#  1   Rent           489 non-null    float64
#  2   PTRATIO        489 non-null    float64
#  3   MEDV           489 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 15.4 KB
# ...
